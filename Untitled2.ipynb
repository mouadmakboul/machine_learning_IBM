# %% [markdown]
# <a href="https://colab.research.google.com/github/mouadmakboul/machine_learning_IBM/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
np.random.seed(0)
X= 2*np.random.rand(200,1)
y= 5+2*X + 2*np.random.rand(200,1)

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

model=LinearRegression()
#appentissage
model.fit(X_train,y_train)
#test
y_predict=model.predict(X_test)
mse= mean_squared_error(y_test,y_predict)
print("MSE : ",mse)
# Out:
# MSE :  0.3856303105454712

# %%
plt.scatter(X,y,color="black")
plt.plot(X_test,y_predict,label= 'Relation Linear')
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.show()
